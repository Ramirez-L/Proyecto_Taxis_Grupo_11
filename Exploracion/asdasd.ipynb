# %%
import pandas as pd
import datetime

# %%
data = pd.read_parquet('../Data/Taxis.parquet')
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2018-01-01 00:21:05   2018-01-01 00:24:23                1
# 1               1  2018-01-01 00:44:55   2018-01-01 01:03:05                1
# 2               1  2018-01-01 00:08:26   2018-01-01 00:14:21                2
# 3               1  2018-01-01 00:20:22   2018-01-01 00:52:51                1
# 4               1  2018-01-01 00:09:18   2018-01-01 00:27:06                2
# ...           ...                  ...                   ...              ...
# 8760682         1  2018-01-31 23:21:35   2018-01-31 23:34:20                2
# 8760683         1  2018-01-31 23:35:51   2018-01-31 23:38:57                1
# 8760684         2  2018-01-31 23:28:00   2018-01-31 23:37:09                1
# 8760685         2  2018-01-31 23:24:40   2018-01-31 23:25:28                1
# 8760686         2  2018-01-31 23:28:16   2018-01-31 23:28:38                1
#
# ...

# %%
data.drop(data[data["tpep_dropoff_datetime"]<datetime.datetime(year=2018, month=1, day=1,hour=0,minute=0,second=0)].index, axis=0, inplace=True)
data.drop(data[data["tpep_dropoff_datetime"]<datetime.datetime(year=2018, month=1, day=1,hour=0,minute=0,second=0)].index, axis=0, inplace=True)
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2018-01-01 00:21:05   2018-01-01 00:24:23                1
# 1               1  2018-01-01 00:44:55   2018-01-01 01:03:05                1
# 2               1  2018-01-01 00:08:26   2018-01-01 00:14:21                2
# 3               1  2018-01-01 00:20:22   2018-01-01 00:52:51                1
# 4               1  2018-01-01 00:09:18   2018-01-01 00:27:06                2
# ...           ...                  ...                   ...              ...
# 8760682         1  2018-01-31 23:21:35   2018-01-31 23:34:20                2
# 8760683         1  2018-01-31 23:35:51   2018-01-31 23:38:57                1
# 8760684         2  2018-01-31 23:28:00   2018-01-31 23:37:09                1
# 8760685         2  2018-01-31 23:24:40   2018-01-31 23:25:28                1
# 8760686         2  2018-01-31 23:28:16   2018-01-31 23:28:38                1
#
# ...

# %%
data[data["tpep_dropoff_datetime"]>=datetime.datetime(year=2018, month=2,day=1)]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1166000         2  2018-07-27 02:22:13   2018-07-27 02:28:28                1
# 1166001         2  2018-07-27 02:42:00   2018-07-27 02:46:56                1
# 1168653         2  2018-07-27 03:16:59   2018-07-27 03:23:37                1
# 1168654         2  2018-07-27 03:34:24   2018-07-27 03:46:39                1
# 1172383         2  2018-07-27 03:55:27   2018-07-27 03:58:08                1
# ...           ...                  ...                   ...              ...
# 8760658         2  2018-01-31 23:53:03   2018-02-01 00:09:22                1
# 8760660         2  2018-01-31 23:55:15   2018-02-01 00:06:49                3
# 8760665         2  2018-01-31 23:35:33   2018-02-01 00:04:11                1
# 8760673         1  2018-01-31 23:54:57   2018-02-01 00:29:56                1
# 8760681         2  2018-01-31 23:57:33   2018-02-01 00:07:44                1
#
# ...

# %%
max(data["tpep_dropoff_datetime"].dt.year)
# Out:
# 2018

# %%
data["tpep_dropoff_datetime"].dt.month.mean()
# Out:
# 1.0002518118524848

# %%
max(data["tpep_dropoff_datetime"].dt.day)
# Out:
# 31
