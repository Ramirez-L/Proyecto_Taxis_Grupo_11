# %%
# pip install pyowm
from datetime import datetime, timedelta, timezone
import pytz
import pandas as pd
import requests

API_KEY="VBF8WCN29MQP5BNCBQ5QG5U7E"

# %%
import urllib.parse
import urllib.request
import json
import time
import matplotlib.pyplot as plt
import pandas as pd

API_KEY="VBF8WCN29MQP5BNCBQ5QG5U7E"
LOCATION="40.7831%2C%20-73.9712"
UNIT_GROUP="us"

def getWeatherForecast():
         requestUrl = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?&aggregateHours=24&startDateTime=2018-01-1T00:00:00&endDateTime=2018-01-31T00:00:00&unitGroup=uk&contentType=csv&dayStartTime=0:0:00&dayEndTime=0:0:00&location={LOCATION}&key={API_KEY}" 
         print('Weather requestUrl={requestUrl}'.format(requestUrl=requestUrl))
         try:
                 req = urllib.request.urlopen(requestUrl)
         except:
                 print("Could not read from:"+requestUrl);
                 return []
         rawForecastData = req.read()
         req.close()
         return rawForecastData
    
weatherForecast = getWeatherForecast()
# Out:
# Weather requestUrl=https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?&aggregateHours=24&startDateTime=2018-01-1T00:00:00&endDateTime=2018-01-31T00:00:00&unitGroup=uk&contentType=csv&dayStartTime=0:0:00&dayEndTime=0:0:00&location=40.7831%2C%20-73.9712&key=VBF8WCN29MQP5BNCBQ5QG5U7E

# %%
# weatherForecast

# %%
with open("./data.csv","w+") as f:
    f.write(weatherForecast.decode())

# %%
dataframe = pd.read_csv("./data.csv")
dataframe
# Out:
#               Address   Date time  Minimum Temperature  Maximum Temperature  \
# 0   40.7831, -73.9712  01/01/2018                -13.8                 -7.8
# 1   40.7831, -73.9712  01/02/2018                -10.9                 -3.3
# 2   40.7831, -73.9712  01/03/2018                 -8.4                 -1.6
# 3   40.7831, -73.9712  01/04/2018                 -6.1                 -1.7
# 4   40.7831, -73.9712  01/05/2018                -12.8                 -7.1
# 5   40.7831, -73.9712  01/06/2018                -13.8                -11.1
# 6   40.7831, -73.9712  01/07/2018                -15.0                 -7.8
# 7   40.7831, -73.9712  01/08/2018                 -8.3                 -0.6
# 8   40.7831, -73.9712  01/09/2018                 -0.7                  6.2
# 9   40.7831, -73.9712  01/10/2018                 -1.2                  5.0
# 10  40.7831, -73.9712  01/11/2018                  5.6                 11.6
# ...
