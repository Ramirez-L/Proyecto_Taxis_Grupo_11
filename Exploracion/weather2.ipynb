# %%
# pip install pyowm
from datetime import datetime, timedelta, timezone
import pytz
import pandas as pd
import requests

API_KEY= "EPVYJQV9TTNYYN52QNYRLEL58" 
# API_KEY= "VBF8WCN29MQP5BNCBQ5QG5U7E"
coords={
    "EWR":{
        "lat":40.6895314,
        "lon":-74.17446239999998,
    },
    "Manhattan":{
        "lat":40.776676,
        "lon":-73.971321,
    },
    "Brooklyn":{
        "lat":40.650002,
        "lon":-73.949997,
        },
    "Bronx":{
        "lat":40.837048,
        "lon":-73.865433,
    },
    "Queens":{
        "lat":40.742054,
        "lon":-73.769417,
    },
    "Staten Island":{
        "lat":40.579021,
        "lon":-74.151535,
    },    
}

# %%
df_coords=pd.DataFrame(coords)
df_coords
# Out:
#            EWR  Manhattan   Brooklyn      Bronx     Queens  Staten Island
# lat  40.689531  40.776676  40.650002  40.837048  40.742054      40.579021
# lon -74.174462 -73.971321 -73.949997 -73.865433 -73.769417     -74.151535

# %%
def get_weather(API_KEY,lat,lon,start,end,freq=24):        
    URL = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history"
    params={
        "aggregateHours":freq,
        "startDateTime":start,
        "endDateTime":end,
        "contentType":"csv",
        "location":f"{lat},{lon}",
        "key":API_KEY,
    }
    try:
        response=requests.request("GET",URL,params=params)
        return response
    except:
        print("Error")

# %%
borough="Manhattan"
formatDate="%Y-%m-%dT%H:%M:%S"

start=datetime(2018, 1, 1,0,0)
end=datetime(2018, 2, 1,0,0)

response=get_weather(
    API_KEY,
    df_coords[borough].lat,
    df_coords[borough].lon,
    start=start.strftime(formatDate),
    end=end.strftime(formatDate),
    freq=1
)

# %%
response.text.count("\n")
# Out:
# 0

# %%
response.text.split("\n",1)[1]
# Out:
# '"40.776676,-73.971321","01/01/2018 00:00:00",8.9,8.9,8.9,-3.9,55.25,,9.2,19.7,300.0,-4.3,0.0,,0.14,9.9,0.0,1026.3,"",40.776676,-73.971321,"40.776676,-73.971321","40.776676,-73.971321","","Clear"\n"40.776676,-73.971321","01/01/2018 01:00:00",8.9,8.9,8.9,-3.9,55.26,,9.2,20.8,300.0,-4.3,0.0,,0.12,9.9,0.0,1026.4,"",40.776676,-73.971321,"40.776676,-73.971321","40.776676,-73.971321","","Clear"\n"40.776676,-73.971321","01/01/2018 02:00:00",8.9,8.9,8.9,-3.9,55.26,,10.3,18.6,290.0,-5.1,0.0,,0.1,9.9,0.0,1026.7,"",40.776676,-73.971321,"40.776676,-73.971321","40.776676,-73.971321","","Clear"\n"40.776676,-73.971321","01/01/2018 03:00:00",8.0,8.0,8.0,-3.9,57.53,,10.3,19.7,310.0,-6.3,0.0,,0.09,9.9,0.0,1027.1,"",40.776676,-73.971321,"40.776676,-73.971321","40.776676,-73.971321","","Clear"\n"40.776676,-73.971321","01/01/2018 04:00:00",8.0,8.0,8.0,-5.0,54.68,,7.0,20.8,310.0,-3.4,0.0,,0.07,9.9,0.0,1027.2,"",40.776676,-73.971321,"40.776676,-73.971321","40.776676,-73.971321","","Clear"\n"40.776676,-73.9
# ...

# %%
file_name=""
if response.text.count("\n")>1:
    file_name=f"weather_{borough}_{start.strftime('%Y-%m-%d')}.csv"
    with open("../Data/"+file_name,"w+") as f:
        f.write(response.text)
        print(f"success: {file_name} Create!")
else:
    print(response.text)
# Out:
# success: weather_Manhattan_2018-01-01.csv Create!

# %%
dataframe = pd.read_csv("../Data/"+file_name)
dataframe.head()
# Out:
#                 Address            Date time  Minimum Temperature  \
# 0  40.776676,-73.971321  01/01/2018 00:00:00                  8.9
# 1  40.776676,-73.971321  01/01/2018 01:00:00                  8.9
# 2  40.776676,-73.971321  01/01/2018 02:00:00                  8.9
# 3  40.776676,-73.971321  01/01/2018 03:00:00                  8.0
# 4  40.776676,-73.971321  01/01/2018 04:00:00                  8.0
#
#    Maximum Temperature  Temperature  Dew Point  Relative Humidity  Heat Index  \
# 0                  8.9          8.9       -3.9              55.25         NaN
# 1                  8.9          8.9       -3.9              55.26         NaN
# 2                  8.9          8.9       -3.9              55.26         NaN
# 3                  8.0          8.0       -3.9              57.53         NaN
# 4                  8.0          8.0       -5.0              54.68         NaN
#
#    Wind Speed  Wind Gust  ...  Visibility  Cloud Cover  Sea Level Pressure  \
# ...

# %%
datetime(2018, 1, 1)-datetime(2018, 2, 1)
# Out:
# datetime.timedelta(days=-31)

# %%
def date_range(start, end,freq="D"):
    delta = end - start  # as timedelta
    if freq == "D":
        time_range = [start + timedelta(days=i) for i in range(delta.days)]
    elif freq == "H":
        time_range = [start + timedelta(hours=i) for i in range(delta.days*24)]
    elif freq == "M":
        time_range = [start + timedelta(minutes=i) for i in range(delta.days*24*60)]
    return time_range

start_date = datetime(2018, 1, 1)
end_date = datetime(2018, 2, 1)
    
dates=date_range(start_date, end_date,"D")
dates
# Out:
# [datetime.datetime(2018, 1, 1, 0, 0),
#  datetime.datetime(2018, 1, 2, 0, 0),
#  datetime.datetime(2018, 1, 3, 0, 0),
#  datetime.datetime(2018, 1, 4, 0, 0),
#  datetime.datetime(2018, 1, 5, 0, 0),
#  datetime.datetime(2018, 1, 6, 0, 0),
#  datetime.datetime(2018, 1, 7, 0, 0),
#  datetime.datetime(2018, 1, 8, 0, 0),
#  datetime.datetime(2018, 1, 9, 0, 0),
#  datetime.datetime(2018, 1, 10, 0, 0),
#  datetime.datetime(2018, 1, 11, 0, 0),
#  datetime.datetime(2018, 1, 12, 0, 0),
#  datetime.datetime(2018, 1, 13, 0, 0),
#  datetime.datetime(2018, 1, 14, 0, 0),
#  datetime.datetime(2018, 1, 15, 0, 0),
#  datetime.datetime(2018, 1, 16, 0, 0),
#  datetime.datetime(2018, 1, 17, 0, 0),
#  datetime.datetime(2018, 1, 18, 0, 0),
#  datetime.datetime(2018, 1, 19, 0, 0),
#  datetime.datetime(2018, 1, 20, 0, 0),
#  datetime.datetime(2018, 1, 21, 0, 0),
#  datetime.datetime(2018, 1, 22, 0, 0),
#  datetime.datetime(2018, 1, 23, 0, 0),
#  datetime.datetime(2018, 1, 24, 0, 0),
# ...

# %%
for i in range(10):
    headers,body="num,num2\ndadas\nasdasd\n".split("\n",1)
    with open("./prueba.txt","a+") as f:
        f.seek(0)
        if f.readline()!=headers+'\n':
            f.write(headers+'\n')
        f.write(f"{i},{i+1}")
        f.write('\n')

# %%
API_LIST = ["API_1","API_2","API_3"]
for i in range(4):
    BURNSTS_APIS=[]
    for API in API_LIST:
        print(i,API)
        if API == "API_1":
            BURNSTS_APIS.append(API)
    for BURNT_API in BURNSTS_APIS:
        API_LIST.remove(BURNT_API)
# Out:
# 0 API_1
# 0 API_2
# 0 API_3
# 1 API_2
# 1 API_3
# 2 API_2
# 2 API_3
# 3 API_2
# 3 API_3

# %%
pd.read_csv("../Data/weather_Manhattan_2018-01.csv")
# Out:
#                   Address            Date time  Minimum Temperature  \
# 0    40.776676,-73.971321  01/01/2018 00:00:00                  8.9
# 1    40.776676,-73.971321  01/01/2018 01:00:00                  8.9
# 2    40.776676,-73.971321  01/01/2018 02:00:00                  8.9
# 3    40.776676,-73.971321  01/01/2018 03:00:00                  8.0
# 4    40.776676,-73.971321  01/01/2018 04:00:00                  8.0
# ..                    ...                  ...                  ...
# 739  40.776676,-73.971321  01/31/2018 19:00:00                 32.1
# 740  40.776676,-73.971321  01/31/2018 20:00:00                 32.1
# 741  40.776676,-73.971321  01/31/2018 21:00:00                 32.1
# 742  40.776676,-73.971321  01/31/2018 22:00:00                 32.1
# 743  40.776676,-73.971321  01/31/2018 23:00:00                 32.1
#
#      Maximum Temperature  Temperature  Dew Point  Relative Humidity  \
# 0                    8.9          8.9       -3.9              55.25
# ...

# %%
# Out:
# 'num,num2\n'
