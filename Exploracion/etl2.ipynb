# %%
import pandas as pd
import numpy as np
from datetime import timedelta

# %%
import sqlalchemy
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy import inspect

HOST="192.53.165.168" #"localhost"
DBNAME="taxisdb"
USER="airflow"
PASS="airflow"

DATABASE_LOCATION=f'postgresql+psycopg2://{USER}:{PASS}@{HOST}:5432/{DBNAME}'
# DATABASE_LOCATION="apachehive:///?Server=127.0.0.1&;Port=10000&TransportMode=BINARY"
engine = sqlalchemy.create_engine(DATABASE_LOCATION,echo=True)
cursor = engine.connect()
# Out:
# 2022-07-14 12:53:07,889 INFO sqlalchemy.engine.Engine select version()
# 2022-07-14 12:53:07,890 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:08,277 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-07-14 12:53:08,277 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:08,665 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-07-14 12:53:08,665 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
sql_query="""
CREATE DATABASE taxisdb;
"""
cursor.execute(sql_query)
try:
    df_vendor.to_sql("vendor", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)

# %%
Vendor= {
    1:"Creative Mobiles Technologies",
    2:"VeriFone Inc."}

df_vendor = pd.DataFrame([[key, Vendor[key]] for key in Vendor.keys()], columns=['id_vendor', 'vendor_name'])
df_vendor
# Out:
#    id_vendor                    vendor_name
# 0          1  Creative Mobiles Technologies
# 1          2                  VeriFone Inc.

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS vendor (
	id_vendor INT UNIQUE PRIMARY KEY,
	vendor_name VARCHAR (100) NOT NULL
);
"""
cursor.execute(sql_query)
try:
    df_vendor.to_sql("vendor", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:09,157 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS vendor (
# 	id_vendor INT UNIQUE PRIMARY KEY,
# 	vendor_name VARCHAR (100) NOT NULL
# );
#
# 2022-07-14 12:53:09,158 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:09,544 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:10,525 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:10,526 INFO sqlalchemy.engine.Engine [generated in 0.00058s] {'name': 'vendor'}
# 2022-07-14 12:53:11,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:11,107 INFO sqlalchemy.engine.Engine INSERT INTO vendor (id_vendor, vendor_name) VALUES (%(id_vendor)s, %(vendor_name)s)
# 2022-07-14 12:53:11,107 INFO sqlalchemy.engine.Engine [generated in 0.00050s] ({'id_vendor': 1, 'vendor_name': 'Creative Mobiles Technologies'}, {'id_vendor': 2, 'vendor_name': 'VeriFone Inc.'})
# 2022-07-14 12:53:11,498 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "vendor_pkey"
# DETAIL:  Key (id_vendor)=(1) already exists.
#
# [SQL: INSERT INTO vendor (id_vendor, vendor_name) VALUES (%(id_vendor)s, %(vendor_name)s)]
# [parameters: ({'id_vendor': 1, 'vendor_name': 'Creative Mobiles Technologies'}, {'id_vendor': 2, 'vendor_name': 'VeriFone Inc.'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
Rate= {
    1:"Standard rate",
    2:"JFK",
    3:"Newark",
    4:"Nassau or Westchester",
    5:"Negotiated fare",
    6:"Group ride"}
df_rate = pd.DataFrame([[key, Rate[key]] for key in Rate.keys()], columns=['id_rate', 'rate_name'])
df_rate
# Out:
#    id_rate              rate_name
# 0        1          Standard rate
# 1        2                    JFK
# 2        3                 Newark
# 3        4  Nassau or Westchester
# 4        5        Negotiated fare
# 5        6             Group ride

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS rate (
	id_rate INT UNIQUE PRIMARY KEY,
	rate_name VARCHAR (100) NOT NULL
);
"""
cursor.execute(sql_query)
try:
    df_rate.to_sql("rate", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:11,751 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS rate (
# 	id_rate INT UNIQUE PRIMARY KEY,
# 	rate_name VARCHAR (100) NOT NULL
# );
#
# 2022-07-14 12:53:11,752 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:12,137 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:12,331 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:12,332 INFO sqlalchemy.engine.Engine [cached since 1.807s ago] {'name': 'rate'}
# 2022-07-14 12:53:12,907 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:12,908 INFO sqlalchemy.engine.Engine INSERT INTO rate (id_rate, rate_name) VALUES (%(id_rate)s, %(rate_name)s)
# 2022-07-14 12:53:12,908 INFO sqlalchemy.engine.Engine [generated in 0.00045s] ({'id_rate': 1, 'rate_name': 'Standard rate'}, {'id_rate': 2, 'rate_name': 'JFK'}, {'id_rate': 3, 'rate_name': 'Newark'}, {'id_rate': 4, 'rate_name': 'Nassau or Westchester'}, {'id_rate': 5, 'rate_name': 'Negotiated fare'}, {'id_rate': 6, 'rate_name': 'Group ride'})
# 2022-07-14 12:53:13,293 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "rate_pkey"
# DETAIL:  Key (id_rate)=(1) already exists.
#
# [SQL: INSERT INTO rate (id_rate, rate_name) VALUES (%(id_rate)s, %(rate_name)s)]
# [parameters: ({'id_rate': 1, 'rate_name': 'Standard rate'}, {'id_rate': 2, 'rate_name': 'JFK'}, {'id_rate': 3, 'rate_name': 'Newark'}, {'id_rate': 4, 'rate_name': 'Nassau or Westchester'}, {'id_rate': 5, 'rate_name': 'Negotiated fare'}, {'id_rate': 6, 'rate_name': 'Group ride'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
Payment= {
    1:"Credit card",
    2:"Cash",
    3:"No charge",
    4:"Dispute",
    5:"Unknown",
    6:"Voided trip"}

df_payment = pd.DataFrame([[key, Payment[key]] for key in Payment.keys()], columns=['id_payment', 'payment_type'])
df_payment
# Out:
#    id_payment payment_type
# 0           1  Credit card
# 1           2         Cash
# 2           3    No charge
# 3           4      Dispute
# 4           5      Unknown
# 5           6  Voided trip

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS payment (
	id_payment INT UNIQUE PRIMARY KEY,
	payment_type VARCHAR (100) NOT NULL
);
"""
cursor.execute(sql_query)
try:
    df_payment.to_sql("payment", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:13,561 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS payment (
# 	id_payment INT UNIQUE PRIMARY KEY,
# 	payment_type VARCHAR (100) NOT NULL
# );
#
# 2022-07-14 12:53:13,562 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:13,947 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:14,140 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:14,141 INFO sqlalchemy.engine.Engine [cached since 3.615s ago] {'name': 'payment'}
# 2022-07-14 12:53:14,717 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:14,718 INFO sqlalchemy.engine.Engine INSERT INTO payment (id_payment, payment_type) VALUES (%(id_payment)s, %(payment_type)s)
# 2022-07-14 12:53:14,719 INFO sqlalchemy.engine.Engine [generated in 0.00067s] ({'id_payment': 1, 'payment_type': 'Credit card'}, {'id_payment': 2, 'payment_type': 'Cash'}, {'id_payment': 3, 'payment_type': 'No charge'}, {'id_payment': 4, 'payment_type': 'Dispute'}, {'id_payment': 5, 'payment_type': 'Unknown'}, {'id_payment': 6, 'payment_type': 'Voided trip'})
# 2022-07-14 12:53:15,105 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "payment_pkey"
# DETAIL:  Key (id_payment)=(1) already exists.
#
# [SQL: INSERT INTO payment (id_payment, payment_type) VALUES (%(id_payment)s, %(payment_type)s)]
# [parameters: ({'id_payment': 1, 'payment_type': 'Credit card'}, {'id_payment': 2, 'payment_type': 'Cash'}, {'id_payment': 3, 'payment_type': 'No charge'}, {'id_payment': 4, 'payment_type': 'Dispute'}, {'id_payment': 5, 'payment_type': 'Unknown'}, {'id_payment': 6, 'payment_type': 'Voided trip'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
registro = {"id_borough": [1, 2, 3, 4, 5],
            "borough": ["Manhattan", "Brooklyn", "Bronx", "Queens", "Staten Island"],
            "latitud": [40.776676, 40.650002, 40.837048, 40.742054, 40.579021],
            "longitud": [-73.971321, -73.949997, -73.865433, -73.769417, -74.151535]
}
df_borough = pd.DataFrame(registro)
df_borough
# Out:
#    id_borough        borough    latitud   longitud
# 0           1      Manhattan  40.776676 -73.971321
# 1           2       Brooklyn  40.650002 -73.949997
# 2           3          Bronx  40.837048 -73.865433
# 3           4         Queens  40.742054 -73.769417
# 4           5  Staten Island  40.579021 -74.151535

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS borough (
	id_borough INT UNIQUE PRIMARY KEY,
	borough VARCHAR (100) NOT NULL,
	latitud FLOAT4 ,
	longitud FLOAT4
);
"""
cursor.execute(sql_query)
try:
    df_borough.to_sql("borough", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:15,410 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS borough (
# 	id_borough INT UNIQUE PRIMARY KEY,
# 	borough VARCHAR (100) NOT NULL,
# 	latitud FLOAT4 ,
# 	longitud FLOAT4
# );
#
# 2022-07-14 12:53:15,411 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:15,795 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:15,990 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:15,990 INFO sqlalchemy.engine.Engine [cached since 5.464s ago] {'name': 'borough'}
# 2022-07-14 12:53:16,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:16,569 INFO sqlalchemy.engine.Engine INSERT INTO borough (id_borough, borough, latitud, longitud) VALUES (%(id_borough)s, %(borough)s, %(latitud)s, %(longitud)s)
# 2022-07-14 12:53:16,569 INFO sqlalchemy.engine.Engine [generated in 0.00070s] ({'id_borough': 1, 'borough': 'Manhattan', 'latitud': 40.776676, 'longitud': -73.971321}, {'id_borough': 2, 'borough': 'Brooklyn', 'latitud': 40.650002, 'longitud': -73.949997}, {'id_borough': 3, 'borough': 'Bronx', 'latitud': 40.837048, 'longitud': -73.865433}, {'id_borough': 4, 'borough': 'Queens', 'latitud': 40.742054, 'longitud': -73.769417}, {'id_borough': 5, 'borough': 'Staten Island', 'latitud': 40.579021, 'longitud': -74.151535})
# 2022-07-14 12:53:16,957 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "borough_pkey"
# DETAIL:  Key (id_borough)=(1) already exists.
#
# [SQL: INSERT INTO borough (id_borough, borough, latitud, longitud) VALUES (%(id_borough)s, %(borough)s, %(latitud)s, %(longitud)s)]
# [parameters: ({'id_borough': 1, 'borough': 'Manhattan', 'latitud': 40.776676, 'longitud': -73.971321}, {'id_borough': 2, 'borough': 'Brooklyn', 'latitud': 40.650002, 'longitud': -73.949997}, {'id_borough': 3, 'borough': 'Bronx', 'latitud': 40.837048, 'longitud': -73.865433}, {'id_borough': 4, 'borough': 'Queens', 'latitud': 40.742054, 'longitud': -73.769417}, {'id_borough': 5, 'borough': 'Staten Island', 'latitud': 40.579021, 'longitud': -74.151535})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
df_location = pd.read_csv("../taxi+_zone_lookup.csv").rename(columns={
    "LocationID":"id_location",
    "Borough":"borough",
    "Zone":"zone",
    "service_zone":"service_zone"
})
# data_location[data_location["Borough"] == "EWR"] ## Solo hay un registro de EWR
df_location.head()
# Out:
#    id_location        borough                     zone service_zone
# 0            1            EWR           Newark Airport          EWR
# 1            2         Queens              Jamaica Bay    Boro Zone
# 2            3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3            4      Manhattan            Alphabet City  Yellow Zone
# 4            5  Staten Island            Arden Heights    Boro Zone

# %%
df_location = df_location.merge(df_borough, how='left', on='borough')
df_location.drop(columns=["borough", "latitud", "longitud"], inplace=True)
df_location = df_location[["id_location", "id_borough", "zone", "service_zone"]]
df_location.dropna(inplace=True)
df_location["id_borough"] = df_location["id_borough"].astype(int)
df_location
# Out:
#      id_location  id_borough                     zone service_zone
# 1              2           4              Jamaica Bay    Boro Zone
# 2              3           3  Allerton/Pelham Gardens    Boro Zone
# 3              4           1            Alphabet City  Yellow Zone
# 4              5           5            Arden Heights    Boro Zone
# 5              6           5  Arrochar/Fort Wadsworth    Boro Zone
# ..           ...         ...                      ...          ...
# 258          259           3       Woodlawn/Wakefield    Boro Zone
# 259          260           4                 Woodside    Boro Zone
# 260          261           1       World Trade Center  Yellow Zone
# 261          262           1           Yorkville East  Yellow Zone
# 262          263           1           Yorkville West  Yellow Zone
#
# [262 rows x 4 columns]

# %%
#df_location.dropna(inplace=True)
df_location["id_borough"] = df_location["id_borough"].astype(int)
df_location
# Out:
#      id_location  id_borough                     zone service_zone
# 1              2           4              Jamaica Bay    Boro Zone
# 2              3           3  Allerton/Pelham Gardens    Boro Zone
# 3              4           1            Alphabet City  Yellow Zone
# 4              5           5            Arden Heights    Boro Zone
# 5              6           5  Arrochar/Fort Wadsworth    Boro Zone
# ..           ...         ...                      ...          ...
# 258          259           3       Woodlawn/Wakefield    Boro Zone
# 259          260           4                 Woodside    Boro Zone
# 260          261           1       World Trade Center  Yellow Zone
# 261          262           1           Yorkville East  Yellow Zone
# 262          263           1           Yorkville West  Yellow Zone
#
# [262 rows x 4 columns]

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS location (
	id_location INT UNIQUE PRIMARY KEY,
	id_borough INT,
	zone VARCHAR (100) NOT NULL,
	service_zone VARCHAR (100) NOT NULL,
	CONSTRAINT fk_borough
      FOREIGN KEY(id_borough) 
	  REFERENCES borough(id_borough)
);
"""
cursor.execute(sql_query)
try:
    df_location.to_sql("location", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:44,662 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS location (
# 	id_location INT UNIQUE PRIMARY KEY,
# 	id_borough INT,
# 	zone VARCHAR (100) NOT NULL,
# 	service_zone VARCHAR (100) NOT NULL,
# 	CONSTRAINT fk_borough
#       FOREIGN KEY(id_borough)
# 	  REFERENCES borough(id_borough)
# );
#
# 2022-07-14 12:53:44,663 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:45,049 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:45,242 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:45,243 INFO sqlalchemy.engine.Engine [cached since 34.72s ago] {'name': 'location'}
# 2022-07-14 12:53:45,820 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:45,822 INFO sqlalchemy.engine.Engine INSERT INTO location (id_location, id_borough, zone, service_zone) VALUES (%(id_location)s, %(id_borough)s, %(zone)s, %(service_zone)s)
# 2022-07-14 12:53:45,823 INFO sqlalchemy.engine.Engine [generated in 0.00102s] ({'id_location': 2, 'id_borough': 4, 'zone': 'Jamaica Bay', 'service_zone': 'Boro Zone'}, {'id_location': 3, 'id_borough': 3, 'zone': 'Allerton/Pelham Gardens', 'service_zone': 'Boro Zone'}, {'id_location': 4, 'id_borough': 1, 'zone': 'Alphabet City', 'service_zone': 'Yellow Zone'}, {'id_location': 5, 'id_borough': 5, 'zone': 'Arden Heights', 'service_zone': 'Boro Zone'}, {'id_location': 6, 'id_borough': 5, 'zone': 'Arrochar/Fort Wadsworth', 'service_zone': 'Boro Zone'}, {'id_location': 7, 'id_borough': 4, 'zone': 'Astoria', 'service_zone': 'Boro Zone'}, {'id_location': 8, 'id_borough': 4, 'zone': 'Astoria Park', 'service_zone': 'Boro Zone'}, {'id_location': 9, 'id_borough': 4, 'zone': 'Auburndale', 'service_zone': 'Boro Zone'}  ... displaying 10 of 262 total bound parameter sets ...  {'id_location': 262, 'id_borough': 1, 'zone': 'Yorkville East', 'service_zone': 'Yellow Zone'}, {'id_location': 263, 'id_borough': 1, 'zone': 'Yorkville West', 'service_zone': 'Yellow Zone'})
# 2022-07-14 12:53:46,211 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "location_pkey"
# DETAIL:  Key (id_location)=(2) already exists.
#
# [SQL: INSERT INTO location (id_location, id_borough, zone, service_zone) VALUES (%(id_location)s, %(id_borough)s, %(zone)s, %(service_zone)s)]
# [parameters: ({'id_location': 2, 'id_borough': 4, 'zone': 'Jamaica Bay', 'service_zone': 'Boro Zone'}, {'id_location': 3, 'id_borough': 3, 'zone': 'Allerton/Pelham Gardens', 'service_zone': 'Boro Zone'}, {'id_location': 4, 'id_borough': 1, 'zone': 'Alphabet City', 'service_zone': 'Yellow Zone'}, {'id_location': 5, 'id_borough': 5, 'zone': 'Arden Heights', 'service_zone': 'Boro Zone'}, {'id_location': 6, 'id_borough': 5, 'zone': 'Arrochar/Fort Wadsworth', 'service_zone': 'Boro Zone'}, {'id_location': 7, 'id_borough': 4, 'zone': 'Astoria', 'service_zone': 'Boro Zone'}, {'id_location': 8, 'id_borough': 4, 'zone': 'Astoria Park', 'service_zone': 'Boro Zone'}, {'id_location': 9, 'id_borough': 4, 'zone': 'Auburndale', 'service_zone': 'Boro Zone'}  ... displaying 10 of 262 total bound parameter sets ...  {'id_location': 262, 'id_borough': 1, 'zone': 'Yorkville East', 'service_zone': 'Yellow Zone'}, {'id_location': 263, 'id_borough': 1, 'zone': 'Yorkville West', 'service_zone': 'Yellow Zone'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
def tabla_calendario(start='2018-01-01', end='2018-12-31'):
    df = pd.DataFrame({"date": pd.date_range(start, end)})
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    df["week"] = df["date"].dt.isocalendar().week
    df["quarter"] = df["date"].dt.quarter
    df["year_half"] = (df["quarter"] + 1) // 2
    df["weekday"] = df["date"].dt.day_of_week
    return df

# %%
df_calendario=tabla_calendario(start='2018-01-01', end='2018-12-31')
df_calendario
# Out:
#           date  year  month  day  week  quarter  year_half  weekday
# 0   2018-01-01  2018      1    1     1        1          1        0
# 1   2018-01-02  2018      1    2     1        1          1        1
# 2   2018-01-03  2018      1    3     1        1          1        2
# 3   2018-01-04  2018      1    4     1        1          1        3
# 4   2018-01-05  2018      1    5     1        1          1        4
# ..         ...   ...    ...  ...   ...      ...        ...      ...
# 360 2018-12-27  2018     12   27    52        4          2        3
# 361 2018-12-28  2018     12   28    52        4          2        4
# 362 2018-12-29  2018     12   29    52        4          2        5
# 363 2018-12-30  2018     12   30    52        4          2        6
# 364 2018-12-31  2018     12   31     1        4          2        0
#
# [365 rows x 8 columns]

# %%
sql_query="""
CREATE TABLE IF NOT EXISTS calendario (
	date date UNIQUE PRIMARY KEY,
	year INT,
	month INT,
	day INT,
	week INT,
	quarter INT,
	year_half INT,
	weekday INT
);
"""
cursor.execute(sql_query)
try:
    df_calendario.to_sql("calendario", con=engine, index=False,if_exists="append")
except Exception as e:  #Want to capture all errors
    print("Shiat broke down ..."+"*"*50)
    print(e)
# Out:
# 2022-07-14 12:53:49,868 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS calendario (
# 	date date UNIQUE PRIMARY KEY,
# 	year INT,
# 	month INT,
# 	day INT,
# 	week INT,
# 	quarter INT,
# 	year_half INT,
# 	weekday INT
# );
#
# 2022-07-14 12:53:49,869 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:53:50,253 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:53:50,448 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:53:50,449 INFO sqlalchemy.engine.Engine [cached since 39.92s ago] {'name': 'calendario'}
# 2022-07-14 12:53:51,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:53:51,029 INFO sqlalchemy.engine.Engine INSERT INTO calendario (date, year, month, day, week, quarter, year_half, weekday) VALUES (%(date)s, %(year)s, %(month)s, %(day)s, %(week)s, %(quarter)s, %(year_half)s, %(weekday)s)
# 2022-07-14 12:53:51,029 INFO sqlalchemy.engine.Engine [generated in 0.00162s] ({'date': datetime.datetime(2018, 1, 1, 0, 0), 'year': 2018, 'month': 1, 'day': 1, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 0}, {'date': datetime.datetime(2018, 1, 2, 0, 0), 'year': 2018, 'month': 1, 'day': 2, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 1}, {'date': datetime.datetime(2018, 1, 3, 0, 0), 'year': 2018, 'month': 1, 'day': 3, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 2}, {'date': datetime.datetime(2018, 1, 4, 0, 0), 'year': 2018, 'month': 1, 'day': 4, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 3}, {'date': datetime.datetime(2018, 1, 5, 0, 0), 'year': 2018, 'month': 1, 'day': 5, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 4}, {'date': datetime.datetime(2018, 1, 6, 0, 0), 'year': 2018, 'month': 1, 'day': 6, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 5}, {'date': datetime.datetime(2018, 1, 7, 0, 0), 'year': 2018, 'month': 1, 'day': 7, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 6}, {'date': datetime.datetime(2018, 1, 8, 0, 0), 'year': 2018, 'month': 1, 'day': 8, 'week': 2, 'quarter': 1, 'year_half': 1, 'weekday': 0}  ... displaying 10 of 365 total bound parameter sets ...  {'date': datetime.datetime(2018, 12, 30, 0, 0), 'year': 2018, 'month': 12, 'day': 30, 'week': 52, 'quarter': 4, 'year_half': 2, 'weekday': 6}, {'date': datetime.datetime(2018, 12, 31, 0, 0), 'year': 2018, 'month': 12, 'day': 31, 'week': 1, 'quarter': 4, 'year_half': 2, 'weekday': 0})
# 2022-07-14 12:53:51,430 INFO sqlalchemy.engine.Engine ROLLBACK
# Shiat broke down ...**************************************************
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "calendario_pkey"
# DETAIL:  Key (date)=(2018-01-01) already exists.
#
# [SQL: INSERT INTO calendario (date, year, month, day, week, quarter, year_half, weekday) VALUES (%(date)s, %(year)s, %(month)s, %(day)s, %(week)s, %(quarter)s, %(year_half)s, %(weekday)s)]
# [parameters: ({'date': datetime.datetime(2018, 1, 1, 0, 0), 'year': 2018, 'month': 1, 'day': 1, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 0}, {'date': datetime.datetime(2018, 1, 2, 0, 0), 'year': 2018, 'month': 1, 'day': 2, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 1}, {'date': datetime.datetime(2018, 1, 3, 0, 0), 'year': 2018, 'month': 1, 'day': 3, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 2}, {'date': datetime.datetime(2018, 1, 4, 0, 0), 'year': 2018, 'month': 1, 'day': 4, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 3}, {'date': datetime.datetime(2018, 1, 5, 0, 0), 'year': 2018, 'month': 1, 'day': 5, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 4}, {'date': datetime.datetime(2018, 1, 6, 0, 0), 'year': 2018, 'month': 1, 'day': 6, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 5}, {'date': datetime.datetime(2018, 1, 7, 0, 0), 'year': 2018, 'month': 1, 'day': 7, 'week': 1, 'quarter': 1, 'year_half': 1, 'weekday': 6}, {'date': datetime.datetime(2018, 1, 8, 0, 0), 'year': 2018, 'month': 1, 'day': 8, 'week': 2, 'quarter': 1, 'year_half': 1, 'weekday': 0}  ... displaying 10 of 365 total bound parameter sets ...  {'date': datetime.datetime(2018, 12, 30, 0, 0), 'year': 2018, 'month': 12, 'day': 30, 'week': 52, 'quarter': 4, 'year_half': 2, 'weekday': 6}, {'date': datetime.datetime(2018, 12, 31, 0, 0), 'year': 2018, 'month': 12, 'day': 31, 'week': 1, 'quarter': 4, 'year_half': 2, 'weekday': 0})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
from pyarrow.parquet import ParquetFile
import pyarrow as pa 

# pf = ParquetFile('../Data/Taxis.parquet') 
# first_n_rows = next(pf.iter_batches(batch_size = 10)) 
# df_taxis = pa.Table.from_batches([first_n_rows]).to_pandas() 

df_taxis = pd.read_parquet("../Data/Taxis.parquet")
df_taxis.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2018-01-01 00:21:05   2018-01-01 00:24:23                1
# 1         1  2018-01-01 00:44:55   2018-01-01 01:03:05                1
# 2         1  2018-01-01 00:08:26   2018-01-01 00:14:21                2
# 3         1  2018-01-01 00:20:22   2018-01-01 00:52:51                1
# 4         1  2018-01-01 00:09:18   2018-01-01 00:27:06                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.5           1                  N            41            24
# 1            2.7           1                  N           239           140
# 2            0.8           1                  N           262           141
# 3           10.2           1                  N           140           257
# 4            2.5           1                  N           246           239
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          4.5    0.5      0.5        0.00           0.0
# 1             2         14.0    0.5      0.5        0.00           0.0
# 2             1          6.0    0.5      0.5        1.00           0.0
# 3             2         33.5    0.5      0.5        0.00           0.0
# 4             1         12.5    0.5      0.5        2.75           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Tiempo_Viaje_s
# 0                    0.3          5.80                   0.0           198.0
# 1                    0.3         15.30                   0.0          1090.0
# 2                    0.3          8.30                   0.0           355.0
# 3                    0.3         34.80                   0.0          1949.0
# 4                    0.3         16.55                   0.0          1068.0

# %%
df_taxis.columns=["id_vendor","pickup_datetime","dropoff_datetime","passager_count","trip_distance","id_rate",
"store_fwd_flag","pu_location","do_location","id_payment","fare_amount","extra","mta_tax","tip_amount","tolls_amount",
"improve_surcharge","total_amount","congestion_surcharge","tiempo_viaje"]
df_taxis.head()
# Out:
#    id_vendor     pickup_datetime    dropoff_datetime  passager_count  \
# 0          1 2018-01-01 00:21:05 2018-01-01 00:24:23               1
# 1          1 2018-01-01 00:44:55 2018-01-01 01:03:05               1
# 2          1 2018-01-01 00:08:26 2018-01-01 00:14:21               2
# 3          1 2018-01-01 00:20:22 2018-01-01 00:52:51               1
# 4          1 2018-01-01 00:09:18 2018-01-01 00:27:06               2
#
#    trip_distance  id_rate store_fwd_flag  pu_location  do_location  \
# 0            0.5        1              N           41           24
# 1            2.7        1              N          239          140
# 2            0.8        1              N          262          141
# 3           10.2        1              N          140          257
# 4            2.5        1              N          246          239
#
#    id_payment  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           2          4.5    0.5      0.5        0.00           0.0
# 1           2         14.0    0.5      0.5        0.00           0.0
# 2           1          6.0    0.5      0.5        1.00           0.0
# 3           2         33.5    0.5      0.5        0.00           0.0
# 4           1         12.5    0.5      0.5        2.75           0.0
#
#    improve_surcharge  total_amount  congestion_surcharge  tiempo_viaje
# 0                0.3          5.80                   0.0         198.0
# 1                0.3         15.30                   0.0        1090.0
# 2                0.3          8.30                   0.0         355.0
# 3                0.3         34.80                   0.0        1949.0
# 4                0.3         16.55                   0.0        1068.0

# %%
from time import time

sql_query="""
CREATE TABLE IF NOT EXISTS trip (

    id_trip SERIAL NOT NULL PRIMARY KEY,

    id_vendor INT NOT NULL,
    pickup_datetime TIMESTAMP NOT NULL,
    dropoff_datetime TIMESTAMP NOT NULL,
    passager_count INT NOT NULL,
    trip_distance DOUBLE PRECISION  NOT NULL,
    id_rate INT NOT NULL,
    store_fwd_flag VARCHAR(4) NOT NULL,
    pu_location INT NOT NULL,
    do_location INT NOT NULL,
    id_payment INT NOT NULL,
    fare_amount DOUBLE PRECISION NOT NULL,
    extra DOUBLE PRECISION NOT NULL,
    mta_tax DOUBLE PRECISION NOT NULL,
    tip_amount DOUBLE PRECISION NOT NULL,
    tolls_amount DOUBLE PRECISION NOT NULL,
    improve_surcharge DOUBLE PRECISION NOT NULL,
    total_amount DOUBLE PRECISION NOT NULL,
    congestion_surcharge DOUBLE PRECISION NOT NULL,
    tiempo_viaje DOUBLE PRECISION NOT NULL,

    CONSTRAINT fk_vendor
      FOREIGN KEY(id_vendor) 
	  REFERENCES vendor(id_vendor),

    CONSTRAINT fk_rate
      FOREIGN KEY(id_rate) 
	  REFERENCES rate(id_rate),

    CONSTRAINT fk_pu_location
      FOREIGN KEY(pu_location) 
	  REFERENCES location(id_location),

    CONSTRAINT fk_do_location
      FOREIGN KEY(do_location)  
	  REFERENCES location(id_location), 

    CONSTRAINT fk_payment 
      FOREIGN KEY(id_payment) 
	  REFERENCES payment(id_payment) 
);
"""
cursor.execute(sql_query)

df_taxis = pd.read_csv("../Data/Taxis.csv", encoding="utf-8",iterator=True, chunksize=100000)
df_taxis.columns=["id_vendor","pickup_datetime","dropoff_datetime","passager_count","trip_distance","id_rate",
"store_fwd_flag","pu_location","do_location","id_payment","fare_amount","extra","mta_tax","tip_amount","tolls_amount",
"improve_surcharge","total_amount","congestion_surcharge","tiempo_viaje"]

df = next(df_taxis)
df.head(n=0).to_sql(name="trip", con=engine, if_exists='replace')

df.to_sql(name="trip", con=engine, if_exists='append')
while True:
        t_start = time()

        df = next(df_taxis)

        df.to_sql(name="trip", con=engine, if_exists='append')

        t_end = time()


        print('insertar otro parte del df... tomo %.3f segundos' %(t_end - t_start))
# Out:
# 2022-07-14 12:56:16,780 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS trip (
#
#     id_trip SERIAL NOT NULL PRIMARY KEY,
#
#     id_vendor INT NOT NULL,
#     pickup_datetime TIMESTAMP NOT NULL,
#     dropoff_datetime TIMESTAMP NOT NULL,
#     passager_count INT NOT NULL,
#     trip_distance DOUBLE PRECISION  NOT NULL,
#     id_rate INT NOT NULL,
#     store_fwd_flag VARCHAR(4) NOT NULL,
#     pu_location INT NOT NULL,
#     do_location INT NOT NULL,
#     id_payment INT NOT NULL,
#     fare_amount DOUBLE PRECISION NOT NULL,
#     extra DOUBLE PRECISION NOT NULL,
#     mta_tax DOUBLE PRECISION NOT NULL,
#     tip_amount DOUBLE PRECISION NOT NULL,
#     tolls_amount DOUBLE PRECISION NOT NULL,
#     improve_surcharge DOUBLE PRECISION NOT NULL,
#     total_amount DOUBLE PRECISION NOT NULL,
#     congestion_surcharge DOUBLE PRECISION NOT NULL,
#     tiempo_viaje DOUBLE PRECISION NOT NULL,
#
#     CONSTRAINT fk_vendor
#       FOREIGN KEY(id_vendor)
# 	  REFERENCES vendor(id_vendor),
#
#     CONSTRAINT fk_rate
#       FOREIGN KEY(id_rate)
# 	  REFERENCES rate(id_rate),
#
#     CONSTRAINT fk_pu_location
#       FOREIGN KEY(pu_location)
# 	  REFERENCES location(id_location),
#
#     CONSTRAINT fk_do_location
#       FOREIGN KEY(do_location)
# 	  REFERENCES location(id_location),
#
#     CONSTRAINT fk_payment
#       FOREIGN KEY(id_payment)
# 	  REFERENCES payment(id_payment)
# );
#
# 2022-07-14 12:56:16,781 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-14 12:56:17,167 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:56:17,499 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:56:17,500 INFO sqlalchemy.engine.Engine [cached since 187s ago] {'name': 'trip'}
# 2022-07-14 12:56:18,079 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:56:18,079 INFO sqlalchemy.engine.Engine [cached since 187.6s ago] {'name': 'trip'}
# 2022-07-14 12:56:18,656 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-07-14 12:56:18,657 INFO sqlalchemy.engine.Engine [cached since 89.71s ago] {'schema': 'public'}
# 2022-07-14 12:56:19,041 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2022-07-14 12:56:19,041 INFO sqlalchemy.engine.Engine [cached since 89.71s ago] {'table_name': 'trip'}
# 2022-07-14 12:56:19,235 INFO sqlalchemy.engine.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (
#                 SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                 WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                 AND a.atthasdef
#               ) AS DEFAULT,
#               a.attnotnull,
#               a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated,
#                               (SELECT json_build_object(
#                     'always', a.attidentity = 'a',
#                     'start', s.seqstart,
#                     'increment', s.seqincrement,
#                     'minvalue', s.seqmin,
#                     'maxvalue', s.seqmax,
#                     'cache', s.seqcache,
#                     'cycle', s.seqcycle)
#                 FROM pg_catalog.pg_sequence s
#                 JOIN pg_catalog.pg_class c on s.seqrelid = c."oid"
#                 WHERE c.relkind = 'S'
#                 AND a.attidentity != ''
#                 AND s.seqrelid = pg_catalog.pg_get_serial_sequence(
#                     a.attrelid::regclass::text, a.attname
#                 )::regclass::oid
#                 ) as identity_options
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2022-07-14 12:56:19,235 INFO sqlalchemy.engine.Engine [cached since 89.71s ago] {'table_oid': 17284}
# 2022-07-14 12:56:19,429 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2022-07-14 12:56:19,430 INFO sqlalchemy.engine.Engine [cached since 89.69s ago] {}
# 2022-07-14 12:56:19,624 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2022-07-14 12:56:19,625 INFO sqlalchemy.engine.Engine [cached since 89.69s ago] {}
# 2022-07-14 12:56:19,819 INFO sqlalchemy.engine.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2022-07-14 12:56:19,820 INFO sqlalchemy.engine.Engine [cached since 89.69s ago] {'table_oid': 17284}
# 2022-07-14 12:56:20,014 INFO sqlalchemy.engine.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2022-07-14 12:56:20,014 INFO sqlalchemy.engine.Engine [cached since 89.69s ago] {'table_oid': 17284}
# 2022-07-14 12:56:20,208 INFO sqlalchemy.engine.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2022-07-14 12:56:20,209 INFO sqlalchemy.engine.Engine [cached since 89.69s ago] {'table': 17284}
# 2022-07-14 12:56:20,402 INFO sqlalchemy.engine.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   pg_get_expr(ix.indpred, ix.indrelid),
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2022-07-14 12:56:20,403 INFO sqlalchemy.engine.Engine [cached since 86.97s ago] {'table_oid': 17284}
# 2022-07-14 12:56:20,597 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2022-07-14 12:56:20,598 INFO sqlalchemy.engine.Engine [cached since 86.97s ago] {'table_oid': 17284}
# 2022-07-14 12:56:20,791 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2022-07-14 12:56:20,792 INFO sqlalchemy.engine.Engine [cached since 86.97s ago] {'table_oid': 17284}
# 2022-07-14 12:56:20,985 INFO sqlalchemy.engine.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2022-07-14 12:56:20,985 INFO sqlalchemy.engine.Engine [cached since 86.96s ago] {'table_oid': 17284}
# 2022-07-14 12:56:21,370 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:56:21,371 INFO sqlalchemy.engine.Engine
# DROP TABLE trip
# 2022-07-14 12:56:21,372 INFO sqlalchemy.engine.Engine [no key 0.00059s] {}
# 2022-07-14 12:56:21,758 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:56:21,958 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:56:21,959 INFO sqlalchemy.engine.Engine
# CREATE TABLE trip (
# 	index BIGINT,
# 	"Unnamed: 0" BIGINT,
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TEXT,
# 	tpep_dropoff_datetime TEXT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Tiempo_Viaje_s" FLOAT(53)
# )
#
#
# 2022-07-14 12:56:21,960 INFO sqlalchemy.engine.Engine [no key 0.00057s] {}
# 2022-07-14 12:56:22,347 INFO sqlalchemy.engine.Engine CREATE INDEX ix_trip_index ON trip (index)
# 2022-07-14 12:56:22,348 INFO sqlalchemy.engine.Engine [no key 0.00058s] {}
# 2022-07-14 12:56:22,542 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:56:22,751 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:56:22,751 INFO sqlalchemy.engine.Engine [cached since 192.2s ago] {'name': 'trip'}
# 2022-07-14 12:56:23,383 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:56:24,421 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:56:24,422 INFO sqlalchemy.engine.Engine [generated in 0.88241s] ({'index': 0, 'Unnamed: 0': 0, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:21:05', 'tpep_dropoff_datetime': '2018-01-01 00:24:23', 'passenger_count': 1, 'trip_distance': 0.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 41, 'DOLocationID': 24, 'payment_type': 2, 'fare_amount': 4.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 198.0}, {'index': 1, 'Unnamed: 0': 1, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:44:55', 'tpep_dropoff_datetime': '2018-01-01 01:03:05', 'passenger_count': 1, 'trip_distance': 2.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 239, 'DOLocationID': 140, 'payment_type': 2, 'fare_amount': 14.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 15.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1090.0}, {'index': 2, 'Unnamed: 0': 2, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:08:26', 'tpep_dropoff_datetime': '2018-01-01 00:14:21', 'passenger_count': 2, 'trip_distance': 0.8, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 262, 'DOLocationID': 141, 'payment_type': 1, 'fare_amount': 6.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 355.0}, {'index': 3, 'Unnamed: 0': 3, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:20:22', 'tpep_dropoff_datetime': '2018-01-01 00:52:51', 'passenger_count': 1, 'trip_distance': 10.2, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 140, 'DOLocationID': 257, 'payment_type': 2, 'fare_amount': 33.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 34.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1949.0}, {'index': 4, 'Unnamed: 0': 4, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:09:18', 'tpep_dropoff_datetime': '2018-01-01 00:27:06', 'passenger_count': 2, 'trip_distance': 2.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 246, 'DOLocationID': 239, 'payment_type': 1, 'fare_amount': 12.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 2.75, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 16.55, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1068.0}, {'index': 5, 'Unnamed: 0': 5, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:29:29', 'tpep_dropoff_datetime': '2018-01-01 00:32:48', 'passenger_count': 3, 'trip_distance': 0.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 143, 'DOLocationID': 143, 'payment_type': 2, 'fare_amount': 4.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 199.0}, {'index': 6, 'Unnamed: 0': 6, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:38:08', 'tpep_dropoff_datetime': '2018-01-01 00:48:24', 'passenger_count': 2, 'trip_distance': 1.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 50, 'DOLocationID': 239, 'payment_type': 1, 'fare_amount': 9.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 2.05, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.35, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 616.0}, {'index': 7, 'Unnamed: 0': 7, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 00:49:29', 'tpep_dropoff_datetime': '2018-01-01 00:51:53', 'passenger_count': 1, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 239, 'DOLocationID': 238, 'payment_type': 1, 'fare_amount': 4.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 144.0}  ... displaying 10 of 100000 t ...
# 2022-07-14 12:56:51,002 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-14 12:56:51,354 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:56:51,355 INFO sqlalchemy.engine.Engine [cached since 220.8s ago] {'name': 'trip'}
# 2022-07-14 12:56:51,988 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:56:53,148 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:56:53,148 INFO sqlalchemy.engine.Engine [generated in 0.92015s] ({'index': 100000, 'Unnamed: 0': 103405, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:09:29', 'tpep_dropoff_datetime': '2018-01-01 11:11:02', 'passenger_count': 1, 'trip_distance': 0.82, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 237, 'DOLocationID': 162, 'payment_type': 2, 'fare_amount': 4.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 93.0}, {'index': 100001, 'Unnamed: 0': 103406, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:15:42', 'tpep_dropoff_datetime': '2018-01-01 11:19:38', 'passenger_count': 1, 'trip_distance': 1.42, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 162, 'DOLocationID': 236, 'payment_type': 1, 'fare_amount': 6.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.46, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.76, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 236.0}, {'index': 100002, 'Unnamed: 0': 103407, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:40:02', 'tpep_dropoff_datetime': '2018-01-01 11:43:56', 'passenger_count': 1, 'trip_distance': 1.05, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 230, 'DOLocationID': 163, 'payment_type': 2, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 234.0}, {'index': 100003, 'Unnamed: 0': 103408, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:46:22', 'tpep_dropoff_datetime': '2018-01-01 11:56:36', 'passenger_count': 1, 'trip_distance': 2.03, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 163, 'DOLocationID': 246, 'payment_type': 2, 'fare_amount': 9.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 10.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 614.0}, {'index': 100004, 'Unnamed: 0': 103409, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:37:44', 'tpep_dropoff_datetime': '2018-01-01 11:52:44', 'passenger_count': 4, 'trip_distance': 2.15, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 161, 'DOLocationID': 43, 'payment_type': 2, 'fare_amount': 11.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 900.0}, {'index': 100005, 'Unnamed: 0': 103410, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:15:39', 'tpep_dropoff_datetime': '2018-01-01 11:23:29', 'passenger_count': 1, 'trip_distance': 1.18, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 48, 'DOLocationID': 230, 'payment_type': 2, 'fare_amount': 7.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 470.0}, {'index': 100006, 'Unnamed: 0': 103411, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:27:59', 'tpep_dropoff_datetime': '2018-01-01 11:32:32', 'passenger_count': 1, 'trip_distance': 0.99, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 230, 'DOLocationID': 246, 'payment_type': 2, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 273.0}, {'index': 100007, 'Unnamed: 0': 103412, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 11:36:36', 'tpep_dropoff_datetime': '2018-01-01 11:40:21', 'passenger_count': 1, 'trip_distance': 0.43, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 246, 'DOLocationID': 48, 'payment_type': 1, 'fare_amount': 4.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.01, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.31, 'cong ...
# 2022-07-14 12:57:19,613 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 28.611 segundos
# 2022-07-14 12:57:19,961 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:57:19,961 INFO sqlalchemy.engine.Engine [cached since 249.4s ago] {'name': 'trip'}
# 2022-07-14 12:57:20,601 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:57:21,643 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:57:21,643 INFO sqlalchemy.engine.Engine [generated in 0.88958s] ({'index': 200000, 'Unnamed: 0': 206638, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:48:37', 'tpep_dropoff_datetime': '2018-01-01 19:57:29', 'passenger_count': 1, 'trip_distance': 2.46, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 158, 'DOLocationID': 50, 'payment_type': 1, 'fare_amount': 9.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.06, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.36, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 532.0}, {'index': 200001, 'Unnamed: 0': 206639, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:38:12', 'tpep_dropoff_datetime': '2018-01-01 19:52:39', 'passenger_count': 1, 'trip_distance': 4.75, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 50, 'DOLocationID': 75, 'payment_type': 1, 'fare_amount': 16.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 4.58, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 22.88, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 867.0}, {'index': 200002, 'Unnamed: 0': 206640, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-01 19:05:05', 'tpep_dropoff_datetime': '2018-01-01 19:29:11', 'passenger_count': 1, 'trip_distance': 13.8, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 132, 'DOLocationID': 155, 'payment_type': 2, 'fare_amount': 38.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 40.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1446.0}, {'index': 200003, 'Unnamed: 0': 206641, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:03:07', 'tpep_dropoff_datetime': '2018-01-01 19:11:14', 'passenger_count': 1, 'trip_distance': 1.15, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 142, 'DOLocationID': 163, 'payment_type': 2, 'fare_amount': 7.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 487.0}, {'index': 200004, 'Unnamed: 0': 206642, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:26:58', 'tpep_dropoff_datetime': '2018-01-01 19:45:58', 'passenger_count': 1, 'trip_distance': 0.89, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 161, 'DOLocationID': 170, 'payment_type': 1, 'fare_amount': 6.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.82, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 9.12, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1140.0}, {'index': 200005, 'Unnamed: 0': 206643, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:56:05', 'tpep_dropoff_datetime': '2018-01-01 20:11:02', 'passenger_count': 1, 'trip_distance': 3.3, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 229, 'DOLocationID': 239, 'payment_type': 1, 'fare_amount': 13.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.38, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 17.13, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 897.0}, {'index': 200006, 'Unnamed: 0': 206644, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:16:02', 'tpep_dropoff_datetime': '2018-01-01 19:26:47', 'passenger_count': 1, 'trip_distance': 1.96, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 186, 'DOLocationID': 79, 'payment_type': 1, 'fare_amount': 9.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.06, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.36, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 645.0}, {'index': 200007, 'Unnamed: 0': 206645, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-01 19:31:13', 'tpep_dropoff_datetime': '2018-01-01 19:35:11', 'passenger_count': 1, 'trip_distance': 0.95, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 107, 'DOLocationID': 170, 'payment_type': 1, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.26, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount ...
# 2022-07-14 12:57:47,905 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 28.293 segundos
# 2022-07-14 12:57:48,250 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:57:48,250 INFO sqlalchemy.engine.Engine [cached since 277.7s ago] {'name': 'trip'}
# 2022-07-14 12:57:48,882 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:57:49,944 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:57:49,945 INFO sqlalchemy.engine.Engine [generated in 0.91004s] ({'index': 300000, 'Unnamed: 0': 309410, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:57:28', 'tpep_dropoff_datetime': '2018-01-02 12:14:24', 'passenger_count': 1, 'trip_distance': 3.17, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 238, 'DOLocationID': 161, 'payment_type': 2, 'fare_amount': 13.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 14.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1016.0}, {'index': 300001, 'Unnamed: 0': 309411, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:10:29', 'tpep_dropoff_datetime': '2018-01-02 11:26:30', 'passenger_count': 2, 'trip_distance': 2.92, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 158, 'DOLocationID': 161, 'payment_type': 2, 'fare_amount': 12.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 13.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 961.0}, {'index': 300002, 'Unnamed: 0': 309412, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:31:45', 'tpep_dropoff_datetime': '2018-01-02 11:51:48', 'passenger_count': 2, 'trip_distance': 3.09, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 161, 'DOLocationID': 238, 'payment_type': 1, 'fare_amount': 15.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 3.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 18.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1203.0}, {'index': 300003, 'Unnamed: 0': 309413, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:02:02', 'tpep_dropoff_datetime': '2018-01-02 11:06:30', 'passenger_count': 2, 'trip_distance': 0.77, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 68, 'DOLocationID': 230, 'payment_type': 2, 'fare_amount': 5.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 268.0}, {'index': 300004, 'Unnamed: 0': 309414, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:31:46', 'tpep_dropoff_datetime': '2018-01-02 11:37:39', 'passenger_count': 2, 'trip_distance': 0.94, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 140, 'DOLocationID': 237, 'payment_type': 2, 'fare_amount': 6.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 353.0}, {'index': 300005, 'Unnamed: 0': 309415, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:48:24', 'tpep_dropoff_datetime': '2018-01-02 11:53:36', 'passenger_count': 2, 'trip_distance': 0.84, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 262, 'DOLocationID': 236, 'payment_type': 1, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.94, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.24, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 312.0}, {'index': 300006, 'Unnamed: 0': 309416, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 11:55:47', 'tpep_dropoff_datetime': '2018-01-02 12:25:04', 'passenger_count': 1, 'trip_distance': 10.2, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 49, 'payment_type': 2, 'fare_amount': 31.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 31.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1757.0}, {'index': 300007, 'Unnamed: 0': 309417, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 11:18:58', 'tpep_dropoff_datetime': '2018-01-02 11:26:06', 'passenger_count': 1, 'trip_distance': 1.77, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 107, 'DOLocationID': 229, 'payment_type': 1, 'fare_amount': 8.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.2, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 10 ...
# 2022-07-14 12:58:16,304 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 28.397 segundos
# 2022-07-14 12:58:16,654 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:58:16,654 INFO sqlalchemy.engine.Engine [cached since 306.1s ago] {'name': 'trip'}
# 2022-07-14 12:58:17,290 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:58:18,514 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:58:18,515 INFO sqlalchemy.engine.Engine [generated in 1.06415s] ({'index': 400000, 'Unnamed: 0': 412221, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 18:34:29', 'tpep_dropoff_datetime': '2018-01-02 18:38:10', 'passenger_count': 2, 'trip_distance': 0.71, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 186, 'DOLocationID': 234, 'payment_type': 1, 'fare_amount': 4.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 1.26, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.56, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 221.0}, {'index': 400001, 'Unnamed: 0': 412222, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 18:39:57', 'tpep_dropoff_datetime': '2018-01-02 18:42:32', 'passenger_count': 2, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 234, 'DOLocationID': 90, 'payment_type': 1, 'fare_amount': 4.0, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 1.45, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.25, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 155.0}, {'index': 400002, 'Unnamed: 0': 412223, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-02 18:52:28', 'tpep_dropoff_datetime': '2018-01-02 19:02:14', 'passenger_count': 2, 'trip_distance': 1.27, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 90, 'DOLocationID': 79, 'payment_type': 1, 'fare_amount': 8.0, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 2.45, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.25, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 586.0}, {'index': 400003, 'Unnamed: 0': 412224, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 18:22:25', 'tpep_dropoff_datetime': '2018-01-02 18:28:40', 'passenger_count': 1, 'trip_distance': 1.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 158, 'DOLocationID': 231, 'payment_type': 1, 'fare_amount': 6.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 1.65, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 9.95, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 375.0}, {'index': 400004, 'Unnamed: 0': 412225, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 18:56:26', 'tpep_dropoff_datetime': '2018-01-02 19:07:10', 'passenger_count': 1, 'trip_distance': 3.9, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 261, 'DOLocationID': 4, 'payment_type': 2, 'fare_amount': 13.0, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 14.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 644.0}, {'index': 400005, 'Unnamed: 0': 412226, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 18:14:57', 'tpep_dropoff_datetime': '2018-01-02 18:25:37', 'passenger_count': 3, 'trip_distance': 0.6, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 230, 'DOLocationID': 186, 'payment_type': 2, 'fare_amount': 8.0, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 9.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 640.0}, {'index': 400006, 'Unnamed: 0': 412227, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 18:31:15', 'tpep_dropoff_datetime': '2018-01-02 18:50:50', 'passenger_count': 3, 'trip_distance': 1.1, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 186, 'DOLocationID': 230, 'payment_type': 1, 'fare_amount': 12.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 2.85, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 17.15, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1175.0}, {'index': 400007, 'Unnamed: 0': 412228, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-02 18:44:33', 'tpep_dropoff_datetime': '2018-01-02 18:56:44', 'passenger_count': 1, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 230, 'DOLocationID': 230, 'payment_type': 2, 'fare_amount': 8.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 10.3, 'c ...
# 2022-07-14 12:58:44,821 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 28.518 segundos
# 2022-07-14 12:58:45,193 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:58:45,193 INFO sqlalchemy.engine.Engine [cached since 334.7s ago] {'name': 'trip'}
# 2022-07-14 12:58:45,843 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:58:47,130 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 12:58:47,131 INFO sqlalchemy.engine.Engine [generated in 1.10793s] ({'index': 500000, 'Unnamed: 0': 514931, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-03 08:56:25', 'tpep_dropoff_datetime': '2018-01-03 09:02:05', 'passenger_count': 1, 'trip_distance': 1.0, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 234, 'DOLocationID': 114, 'payment_type': 1, 'fare_amount': 6.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.35, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.15, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 340.0}, {'index': 500001, 'Unnamed: 0': 514932, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-03 08:15:28', 'tpep_dropoff_datetime': '2018-01-03 08:20:02', 'passenger_count': 1, 'trip_distance': 0.9, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 141, 'DOLocationID': 236, 'payment_type': 2, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 274.0}, {'index': 500002, 'Unnamed: 0': 514933, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-03 08:12:58', 'tpep_dropoff_datetime': '2018-01-03 08:28:18', 'passenger_count': 1, 'trip_distance': 2.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 25, 'DOLocationID': 45, 'payment_type': 1, 'fare_amount': 12.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.7, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 16.0, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 920.0}, {'index': 500003, 'Unnamed: 0': 514934, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-03 08:49:33', 'tpep_dropoff_datetime': '2018-01-03 08:53:49', 'passenger_count': 1, 'trip_distance': 0.6, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 249, 'DOLocationID': 68, 'payment_type': 1, 'fare_amount': 4.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.05, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.35, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 256.0}, {'index': 500004, 'Unnamed: 0': 514935, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-03 08:08:01', 'tpep_dropoff_datetime': '2018-01-03 08:21:45', 'passenger_count': 5, 'trip_distance': 1.07, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 142, 'DOLocationID': 230, 'payment_type': 1, 'fare_amount': 10.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.16, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.96, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 824.0}, {'index': 500005, 'Unnamed: 0': 514936, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-03 08:27:42', 'tpep_dropoff_datetime': '2018-01-03 08:36:44', 'passenger_count': 5, 'trip_distance': 1.05, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 48, 'DOLocationID': 43, 'payment_type': 1, 'fare_amount': 8.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 1.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 9.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 542.0}, {'index': 500006, 'Unnamed: 0': 514937, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-03 05:41:24', 'tpep_dropoff_datetime': '2018-01-03 08:58:01', 'passenger_count': 1, 'trip_distance': 0.01, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 113, 'DOLocationID': 230, 'payment_type': 2, 'fare_amount': 2.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 3.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 11797.0}, {'index': 500007, 'Unnamed: 0': 514938, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-03 08:08:37', 'tpep_dropoff_datetime': '2018-01-03 08:11:27', 'passenger_count': 1, 'trip_distance': 0.63, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 166, 'DOLocationID': 166, 'payment_type': 1, 'fare_amount': 4.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 7.3, 'cong ...
# 2022-07-14 12:59:13,454 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 28.632 segundos
# 2022-07-14 12:59:13,811 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 12:59:13,812 INFO sqlalchemy.engine.Engine [cached since 363.3s ago] {'name': 'trip'}
# 2022-07-14 12:59:14,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 12:59:15,622 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# ...
# 2022-07-14 13:36:42,220 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 29.267 segundos
# 2022-07-14 13:36:42,559 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 13:36:42,559 INFO sqlalchemy.engine.Engine [cached since 2612s ago] {'name': 'trip'}
# 2022-07-14 13:36:43,182 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 13:36:44,327 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 13:36:44,328 INFO sqlalchemy.engine.Engine [generated in 0.98352s] ({'index': 8400000, 'Unnamed: 0': 8594699, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 14:57:30', 'tpep_dropoff_datetime': '2018-01-31 14:58:50', 'passenger_count': 1, 'trip_distance': 0.2, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 237, 'DOLocationID': 237, 'payment_type': 1, 'fare_amount': 3.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.75, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 4.55, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 80.0}, {'index': 8400001, 'Unnamed: 0': 8594700, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 14:10:36', 'tpep_dropoff_datetime': '2018-01-31 14:38:34', 'passenger_count': 1, 'trip_distance': 2.9, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 236, 'DOLocationID': 170, 'payment_type': 1, 'fare_amount': 17.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 3.65, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 21.95, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1678.0}, {'index': 8400002, 'Unnamed: 0': 8594701, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 14:58:52', 'tpep_dropoff_datetime': '2018-01-31 15:04:03', 'passenger_count': 1, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 170, 'DOLocationID': 107, 'payment_type': 2, 'fare_amount': 5.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 5.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 311.0}, {'index': 8400003, 'Unnamed: 0': 8594702, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 14:09:41', 'tpep_dropoff_datetime': '2018-01-31 14:15:30', 'passenger_count': 1, 'trip_distance': 0.77, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 68, 'DOLocationID': 68, 'payment_type': 2, 'fare_amount': 5.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.3, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 349.0}, {'index': 8400004, 'Unnamed: 0': 8594703, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 14:19:50', 'tpep_dropoff_datetime': '2018-01-31 14:35:12', 'passenger_count': 1, 'trip_distance': 2.01, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 68, 'DOLocationID': 163, 'payment_type': 1, 'fare_amount': 11.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.46, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 14.76, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 922.0}, {'index': 8400005, 'Unnamed: 0': 8594704, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 14:36:33', 'tpep_dropoff_datetime': '2018-01-31 14:49:44', 'passenger_count': 1, 'trip_distance': 1.15, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 163, 'DOLocationID': 162, 'payment_type': 1, 'fare_amount': 9.5, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.58, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 12.88, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 791.0}, {'index': 8400006, 'Unnamed: 0': 8594705, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 14:55:42', 'tpep_dropoff_datetime': '2018-01-31 15:26:21', 'passenger_count': 1, 'trip_distance': 5.02, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 161, 'DOLocationID': 148, 'payment_type': 1, 'fare_amount': 23.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 25.8, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 1839.0}, {'index': 8400007, 'Unnamed: 0': 8594706, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 14:09:20', 'tpep_dropoff_datetime': '2018-01-31 14:27:50', 'passenger_count': 1, 'trip_distance': 3.0, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 231, 'DOLocationID': 137, 'payment_type': 1, 'fare_amount': 14.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 2.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'to ...
# 2022-07-14 13:37:13,607 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 31.388 segundos
# 2022-07-14 13:37:13,901 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-14 13:37:13,902 INFO sqlalchemy.engine.Engine [cached since 2643s ago] {'name': 'trip'}
# 2022-07-14 13:37:14,511 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-14 13:37:15,160 INFO sqlalchemy.engine.Engine INSERT INTO trip (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, "Tiempo_Viaje_s") VALUES (%(index)s, %(Unnamed: 0)s, %(VendorID)s, %(tpep_pickup_datetime)s, %(tpep_dropoff_datetime)s, %(passenger_count)s, %(trip_distance)s, %(RatecodeID)s, %(store_and_fwd_flag)s, %(PULocationID)s, %(DOLocationID)s, %(payment_type)s, %(fare_amount)s, %(extra)s, %(mta_tax)s, %(tip_amount)s, %(tolls_amount)s, %(improvement_surcharge)s, %(total_amount)s, %(congestion_surcharge)s, %(Tiempo_Viaje_s)s)
# 2022-07-14 13:37:15,160 INFO sqlalchemy.engine.Engine [generated in 0.55391s] ({'index': 8500000, 'Unnamed: 0': 8697222, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 20:23:49', 'tpep_dropoff_datetime': '2018-01-31 20:29:07', 'passenger_count': 1, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 246, 'DOLocationID': 186, 'payment_type': 1, 'fare_amount': 5.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.35, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.15, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 318.0}, {'index': 8500001, 'Unnamed: 0': 8697223, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 20:36:48', 'tpep_dropoff_datetime': '2018-01-31 20:40:23', 'passenger_count': 1, 'trip_distance': 0.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 100, 'DOLocationID': 48, 'payment_type': 1, 'fare_amount': 4.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.16, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 6.96, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 215.0}, {'index': 8500002, 'Unnamed: 0': 8697224, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 20:47:53', 'tpep_dropoff_datetime': '2018-01-31 20:54:54', 'passenger_count': 2, 'trip_distance': 0.6, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 230, 'DOLocationID': 163, 'payment_type': 1, 'fare_amount': 6.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.45, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.75, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 421.0}, {'index': 8500003, 'Unnamed: 0': 8697225, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 20:18:07', 'tpep_dropoff_datetime': '2018-01-31 20:33:12', 'passenger_count': 6, 'trip_distance': 3.59, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 170, 'DOLocationID': 263, 'payment_type': 1, 'fare_amount': 13.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 2.96, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 17.76, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 905.0}, {'index': 8500004, 'Unnamed: 0': 8697226, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 20:06:22', 'tpep_dropoff_datetime': '2018-01-31 20:14:24', 'passenger_count': 2, 'trip_distance': 0.9, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 233, 'DOLocationID': 100, 'payment_type': 1, 'fare_amount': 6.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.55, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 9.35, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 482.0}, {'index': 8500005, 'Unnamed: 0': 8697227, 'VendorID': 1, 'tpep_pickup_datetime': '2018-01-31 20:15:40', 'tpep_dropoff_datetime': '2018-01-31 20:20:50', 'passenger_count': 1, 'trip_distance': 1.0, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 100, 'DOLocationID': 50, 'payment_type': 1, 'fare_amount': 6.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 0.73, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 8.03, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 310.0}, {'index': 8500006, 'Unnamed: 0': 8697228, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 20:03:15', 'tpep_dropoff_datetime': '2018-01-31 20:13:10', 'passenger_count': 1, 'trip_distance': 0.83, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 170, 'DOLocationID': 68, 'payment_type': 1, 'fare_amount': 7.5, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.76, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'total_amount': 10.56, 'congestion_surcharge': 0.0, 'Tiempo_Viaje_s': 595.0}, {'index': 8500007, 'Unnamed: 0': 8697229, 'VendorID': 2, 'tpep_pickup_datetime': '2018-01-31 20:40:14', 'tpep_dropoff_datetime': '2018-01-31 20:44:51', 'passenger_count': 1, 'trip_distance': 0.67, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 142, 'DOLocationID': 143, 'payment_type': 1, 'fare_amount': 5.0, 'extra': 0.5, 'mta_tax': 0.5, 'tip_amount': 1.0, 'tolls_amount': 0.0, 'improvement_surcharge': 0.3, 'tot ...
# 2022-07-14 13:37:31,660 INFO sqlalchemy.engine.Engine COMMIT
# insertar otro parte del df... tomo 18.048 segundos
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3576/1675570202.py in <module>
#      61         t_start = time()
#      62
# ---> 63         df = next(df_taxis)
#      64
#      65         df.to_sql(name="trip", con=engine, if_exists='append')
#
# c:\Users\Nacho\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __next__(self)
#    1022     def __next__(self):
#    1023         try:
# -> 1024             return self.get_chunk()
#    1025         except StopIteration:
#    1026             self.close()
#
# c:\Users\Nacho\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in get_chunk(self, size)
#    1072                 raise StopIteration
#    1073             size = min(size, self.nrows - self._currow)
# -> 1074         return self.read(nrows=size)
#    1075
#    1076     def __enter__(self):
#
# c:\Users\Nacho\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# c:\Users\Nacho\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# c:\Users\Nacho\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
